# %%
pip install opencv-python dlib numpy face-recognition
# Out:
# Requirement already satisfied: opencv-python in c:\users\asus\anaconda3\anaconda\lib\site-packages (4.9.0.80)Note: you may need to restart the kernel to use updated packages.
#
# Collecting dlib
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install --upgrade setuptools wheel
# Out:
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (75.7.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: wheel in c:\users\asus\anaconda3\anaconda\lib\site-packages (0.41.2)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.41.2
#     Uninstalling wheel-0.41.2:
#       Successfully uninstalled wheel-0.41.2
# Successfully installed wheel-0.45.1

# %%
pip install opencv-python dlib numpy face-recognition
# Out:
# Requirement already satisfied: opencv-python in c:\users\asus\anaconda3\anaconda\lib\site-packages (4.9.0.80)Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting dlib
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'

# %%
pip install C:/Users/Asus/Downloads/dlib-19.24.1-cp311-cp311-win_amd64.whl
# Out:
# Processing c:\users\asus\downloads\dlib-19.24.1-cp311-cp311-win_amd64.whl
# Installing collected packages: dlib
# Successfully installed dlib-19.24.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python dlib numpy face-recognition
# Out:
# Requirement already satisfied: opencv-python in c:\users\asus\anaconda3\anaconda\lib\site-packages (4.9.0.80)
# Requirement already satisfied: dlib in c:\users\asus\anaconda3\anaconda\lib\site-packages (19.24.1)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\anaconda\lib\site-packages (1.26.4)
# Collecting face-recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face-recognition)
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Click>=6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from face-recognition) (8.1.7)
# Requirement already satisfied: Pillow in c:\users\asus\anaconda3\anaconda\lib\site-packages (from face-recognition) (10.2.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Click>=6.0->face-recognition) (0.4.6)
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import face_recognition
import numpy as np
import os
from datetime import datetime

# Path to student images folder
STUDENT_IMAGES_PATH = "C:/Users/Asus/Videos/images"
ATTENDANCE_FILE = "attendance.csv"

# Load student images and names
def load_students():
    student_images = []
    student_names = []
    for file_name in os.listdir(STUDENT_IMAGES_PATH):
        image_path = os.path.join(STUDENT_IMAGES_PATH, file_name)
        image = face_recognition.load_image_file(image_path)
        student_images.append(image)
        student_names.append(os.path.splitext(file_name)[0])
    return student_images, student_names

# Encode faces from images
def encode_faces(images):
    encodings = []
    for img in images:
        encoding = face_recognition.face_encodings(img)[0]
        encodings.append(encoding)
    return encodings

# Mark attendance in a CSV file
def mark_attendance(name):
    with open(ATTENDANCE_FILE, "a") as file:
        now = datetime.now()
        time_stamp = now.strftime("%Y-%m-%d %H:%M:%S")
        file.write(f"{name},{time_stamp}\n")

# Load students and encode their faces
student_images, student_names = load_students()
student_encodings = encode_faces(student_images)

# Initialize webcam or CCTV feed
video_capture = cv2.VideoCapture(simulated2_cctv.mp4)  # Change 0 to video file path if using a video file

print("Starting attendance detection...")
while True:
    ret, frame = video_capture.read()
    if not ret:
        break

    # Resize frame for faster processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)
    rgb_small_frame = small_frame[:, :, ::-1]

    # Detect faces and encode them
    face_locations = face_recognition.face_locations(rgb_small_frame)
    face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

    for face_encoding, face_location in zip(face_encodings, face_locations):
        # Compare detected faces with known faces
        matches = face_recognition.compare_faces(student_encodings, face_encoding)
        face_distances = face_recognition.face_distance(student_encodings, face_encoding)

        # Select the closest match
        if any(matches):
            best_match_index = np.argmin(face_distances)
            name = student_names[best_match_index]
            mark_attendance(name)

            # Draw a rectangle around the face and show name
            top, right, bottom, left = [v * 4 for v in face_location]
            cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
            cv2.putText(frame, name, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    # Display the video feed
    cv2.imshow('Attendance Detection', frame)

    # Quit with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
video_capture.release()
cv2.destroyAllWindows()
print("Attendance detection stopped.")
# Out:
# Please install `face_recognition_models` with this command before using `face_recognition`:
#
# pip install git+https://github.com/ageitgey/face_recognition_models
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\anaconda\Lib\site-packages\face_recognition\api.py:9
#       8 try:
# ----> 9     import face_recognition_models
#      10 except Exception:
#
# File ~\anaconda3\anaconda\Lib\site-packages\face_recognition_models\__init__.py:7
#       5 __version__ = '0.1.0'
# ----> 7 from pkg_resources import resource_filename
#       9 def pose_predictor_model_location():
#
# File ~\anaconda3\anaconda\Lib\site-packages\pkg_resources\__init__.py:90
#      89 import packaging.version
# ---> 90 from jaraco.text import drop_comment, join_continuation, yield_lines
#      91 from platformdirs import user_cache_dir as _user_cache_dir
#
# File ~\anaconda3\anaconda\Lib\site-packages\setuptools\_vendor\jaraco\text\__init__.py:12
#      11 from jaraco.functools import compose, method_cache
# ---> 12 from jaraco.context import ExceptionTrap
#      15 def substitution(old, new):
#
# File ~\anaconda3\anaconda\Lib\site-packages\setuptools\_vendor\jaraco\context.py:17
#      16 if sys.version_info < (3, 12):
# ---> 17     from backports import tarfile
#      18 else:
#
# ImportError: cannot import name 'tarfile' from 'backports' (C:\Users\Asus\anaconda3\anaconda\Lib\site-packages\backports\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 import face_recognition
#       3 import numpy as np
#       4 import os
#
# File ~\anaconda3\anaconda\Lib\site-packages\face_recognition\__init__.py:7
#       4 __email__ = 'ageitgey@gmail.com'
#       5 __version__ = '1.2.3'
# ----> 7 from .api import load_image_file, face_locations, batch_face_locations, face_landmarks, face_encodings, compare_faces, face_distance
#
# File ~\anaconda3\anaconda\Lib\site-packages\face_recognition\api.py:13
#      11     print("Please install `face_recognition_models` with this command before using `face_recognition`:\n")
#      12     print("pip install git+https://github.com/ageitgey/face_recognition_models")
# ---> 13     quit()
#      15 ImageFile.LOAD_TRUNCATED_IMAGES = True
#      17 face_detector = dlib.get_frontal_face_detector()
#
# NameError: name 'quit' is not defined

# %%
pip install face_recognition_models
# Out:
# Requirement already satisfied: face_recognition_models in c:\users\asus\anaconda3\anaconda\lib\site-packages (0.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall backports
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping backports as it is not installed.

# %%
pip install backports.tarfile
# Out:
# Collecting backports.tarfile
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Installing collected packages: backports.tarfile
# Successfully installed backports.tarfile-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import face_recognition
import numpy as np
import os
from datetime import datetime

# Path to student images folder
STUDENT_IMAGES_PATH = "C:/Users/Asus/Videos/images"
ATTENDANCE_FILE = "attendance.csv"

# Load student images and names
def load_students():
    student_images = []
    student_names = []
    for file_name in os.listdir(STUDENT_IMAGES_PATH):
        image_path = os.path.join(STUDENT_IMAGES_PATH, file_name)
        try:
            image = face_recognition.load_image_file(image_path)
            student_images.append(image)
            student_names.append(os.path.splitext(file_name)[0])
        except Exception as e:
            print(f"Error loading image {file_name}: {e}")
    return student_images, student_names

# Encode faces from images
def encode_faces(images):
    encodings = []
    for img in images:
        try:
            encoding = face_recognition.face_encodings(img)[0]  # Get the first face encoding
            encodings.append(encoding)
        except IndexError:
            print("No face detected in one of the images.")
    return encodings

# Mark attendance in a CSV file
def mark_attendance(name):
    with open(ATTENDANCE_FILE, "a") as file:
        now = datetime.now()
        time_stamp = now.strftime("%Y-%m-%d %H:%M:%S")
        file.write(f"{name},{time_stamp}\n")

# Load students and encode their faces
print("Loading student images...")
student_images, student_names = load_students()
print("Encoding student faces...")
student_encodings = encode_faces(student_images)

# Initialize webcam or video file
VIDEO_PATH = "C:/Users/Asus/Downloads/Untitled_Project_V2.mp4"
video_capture = cv2.VideoCapture(VIDEO_PATH)  # Use 0 for webcam, or provide a video file path

print("Starting attendance detection...")
while True:
    ret, frame = video_capture.read()
    if not ret:
        print("End of video or camera feed.")
        break

    # Resize frame for faster processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)
    rgb_small_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

    # Detect faces and encode them
    face_locations = face_recognition.face_locations(rgb_small_frame)
    if len(face_locations) > 0:
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)
    else:
        face_encodings = []

    for face_encoding, face_location in zip(face_encodings, face_locations):
        # Compare detected faces with known faces
        matches = face_recognition.compare_faces(student_encodings, face_encoding)
        face_distances = face_recognition.face_distance(student_encodings, face_encoding)

        # Select the closest match
        if any(matches):
            best_match_index = np.argmin(face_distances)
            name = student_names[best_match_index]
            mark_attendance(name)

            # Draw a rectangle around the face and display the name
            top, right, bottom, left = [v * 4 for v in face_location]
            cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
            cv2.putText(frame, name, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    # Display the video feed
    cv2.imshow('Attendance Detection', frame)

    # Quit with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
video_capture.release()
cv2.destroyAllWindows()
print("Attendance detection stopped.")
# Out:
# Loading student images...
# Encoding student faces...
# Starting attendance detection...
# End of video or camera feed.
# Attendance detection stopped.

# %%
pip install mtcnn tensorflow keras opencv-python
# Out:
# Collecting mtcnn
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow in c:\users\asus\anaconda3\anaconda\lib\site-packages (2.18.0)
# Requirement already satisfied: keras in c:\users\asus\anaconda3\anaconda\lib\site-packages (3.7.0)
# Requirement already satisfied: opencv-python in c:\users\asus\anaconda3\anaconda\lib\site-packages (4.9.0.80)
# Collecting joblib>=1.4.2 (from mtcnn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting lz4>=4.3.3 (from mtcnn)
#   Downloading lz4-4.3.3-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (0.13.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.9 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 2.1 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading lz4-4.3.3-cp311-cp311-win_amd64.whl (99 kB)
# Installing collected packages: lz4, joblib, mtcnn
#   Attempting uninstall: lz4
#     Found existing installation: lz4 4.3.2
#     Uninstalling lz4-4.3.2:
#       Successfully uninstalled lz4-4.3.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# Successfully installed joblib-1.4.2 lz4-4.3.3 mtcnn-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from datetime import datetime
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
from mtcnn import MTCNN  # For face detection

# Path to student images folder
STUDENT_IMAGES_PATH = "C:/Users/Asus/Videos/images"
ATTENDANCE_FILE = "attendance.csv"

# Load MTCNN for face detection
detector = MTCNN()

# Load pretrained FaceNet model for face encoding
facenet_model = load_model("C:/Users/Asus/Downloads/model-20250107T101226Z-001/model/facenet_keras.h5")  # You need to download the FaceNet model

# Load student images and create encodings
def load_and_encode_students():
    student_encodings = []
    student_names = []
    for file_name in os.listdir(STUDENT_IMAGES_PATH):
        image_path = os.path.join(STUDENT_IMAGES_PATH, file_name)
        image = cv2.imread(image_path)
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Detect the face in the image
        detection = detector.detect_faces(rgb_image)
        if detection:
            x, y, width, height = detection[0]['box']
            face = rgb_image[y:y+height, x:x+width]

            # Preprocess the face for FaceNet
            face = cv2.resize(face, (160, 160))  # FaceNet expects 160x160 images
            face = face.astype('float32') / 255.0
            face = np.expand_dims(face, axis=0)

            # Get face encoding
            encoding = facenet_model.predict(face)[0]
            student_encodings.append(encoding)
            student_names.append(os.path.splitext(file_name)[0])

    return student_encodings, student_names

# Function to calculate cosine similarity between two encodings
def cosine_similarity(encoding1, encoding2):
    return np.dot(encoding1, encoding2) / (np.linalg.norm(encoding1) * np.linalg.norm(encoding2))

# Mark attendance in a CSV file
def mark_attendance(name):
    with open(ATTENDANCE_FILE, "a") as file:
        now = datetime.now()
        time_stamp = now.strftime("%Y-%m-%d %H:%M:%S")
        file.write(f"{name},{time_stamp}\n")

# Load students and encode their faces
student_encodings, student_names = load_and_encode_students()

# Initialize webcam or CCTV feed
video_capture = cv2.VideoCapture("C:/Users/Asus/Downloads/Untitled_Project_V2.mp4")  # Change 0 to use webcam

print("Starting attendance detection...")
while True:
    ret, frame = video_capture.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    detections = detector.detect_faces(rgb_frame)
    for detection in detections:
        x, y, width, height = detection['box']
        face = rgb_frame[y:y+height, x:x+width]

        # Preprocess the face
        face = cv2.resize(face, (160, 160))
        face = face.astype('float32') / 255.0
        face = np.expand_dims(face, axis=0)

        # Get encoding for the detected face
        face_encoding = facenet_model.predict(face)[0]

        # Compare with known encodings
        similarities = [cosine_similarity(face_encoding, student_encoding) for student_encoding in student_encodings]
        best_match_index = np.argmax(similarities)

        # If similarity exceeds a threshold, mark attendance
        if similarities[best_match_index] > 0.8:  # Adjust the threshold as needed
            name = student_names[best_match_index]
            mark_attendance(name)

            # Draw a rectangle around the face and show name
            cv2.rectangle(frame, (x, y), (x+width, y+height), (0, 255, 0), 2)
            cv2.putText(frame, name, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    # Display the video feed
    cv2.imshow('Attendance Detection', frame)

    # Quit with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
video_capture.release()
cv2.destroyAllWindows()
print("Attendance detection stopped.")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[4], line 17
#      14 detector = MTCNN()
#      16 # Load pretrained FaceNet model for face encoding
# ---> 17 facenet_model = load_model("C:/Users/Asus/Downloads/model-20250107T101226Z-001/model/facenet_keras.h5")  # You need to download the FaceNet model
#      19 # Load student images and create encodings
#      20 def load_and_encode_students():
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\models\model.py:527, in Model.from_config(cls, config, custom_objects)
#     522 if is_functional_config and revivable_as_functional:
#     523     # Revive Functional model
#     524     # (but not Functional subclasses with a custom __init__)
#     525     from keras.src.models.functional import functional_from_config
# --> 527     return functional_from_config(
#     528         cls, config, custom_objects=custom_objects
#     529     )
#     531 # Either the model has a custom __init__, or the config
#     532 # does not contain all the information necessary to
#     533 # revive a Functional model. This happens when the user creates
#    (...)
#     536 # In this case, we fall back to provide all config into the
#     537 # constructor of the class.
#     538 try:
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\models\functional.py:546, in functional_from_config(cls, config, custom_objects)
#     544 # First, we create all layers and enqueue nodes to be processed
#     545 for layer_data in functional_config["layers"]:
# --> 546     process_layer(layer_data)
#     548 # Then we process nodes in order of layer depth.
#     549 # Nodes that cannot yet be processed (if the inbound node
#     550 # does not yet exist) are re-enqueued, and the process
#     551 # is repeated until all nodes are processed.
#     552 while unprocessed_nodes:
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\models\functional.py:514, in functional_from_config.<locals>.process_layer(layer_data)
#     510 # Instantiate layer.
#     511 if "module" not in layer_data:
#     512     # Legacy format deserialization (no "module" key)
#     513     # used for H5 and SavedModel formats
# --> 514     layer = saving_utils.model_from_config(
#     515         layer_data, custom_objects=custom_objects
#     516     )
#     517 else:
#     518     layer = serialization_lib.deserialize_keras_object(
#     519         layer_data, custom_objects=custom_objects
#     520     )
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\layers\core\lambda_layer.py:192, in Lambda.from_config(cls, config, custom_objects, safe_mode)
#     190     cls._raise_for_lambda_deserialization("function", safe_mode)
#     191     inner_config = fn_config["config"]
# --> 192     fn = python_utils.func_load(
#     193         inner_config["code"],
#     194         defaults=inner_config["defaults"],
#     195         closure=inner_config["closure"],
#     196     )
#     197     config["function"] = fn
#     198 else:
#
# File ~\anaconda3\anaconda\Lib\site-packages\keras\src\utils\python_utils.py:83, in func_load(code, defaults, closure, globs)
#      81 except (UnicodeEncodeError, binascii.Error):
#      82     raw_code = code.encode("raw_unicode_escape")
# ---> 83 code = marshal.loads(raw_code)
#      84 if globs is None:
#      85     globs = globals()
#
# EOFError: EOF read where object expected

# %%
try:
    facenet_model = load_model("C:/Users/Asus/Downloads/model-20250107T101226Z-001/model/facenet_keras.h5")
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Error loading model: EOF read where object expected

# %%
pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.1.4)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (10.2.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (4.9.0.80)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.18.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (3.7.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.2.5)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (1.0.0)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: termcolor in c:\users\asus\anaconda3\anaconda\lib\site-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: absl-py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (3.12.1)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.4.1)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2024.2.2)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (75.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114262 sha256=c0458f4ddf533c617210051117bc39c2706e98c7f6bd2eb8e033e07177f6c779
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\46\54\24\1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: gunicorn, fire, gdown, flask-cors, retina-face, deepface
# Successfully installed deepface-0.0.93 fire-0.7.0 flask-cors-5.0.0 gdown-5.2.0 gunicorn-23.0.0 retina-face-0.0.17
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from datetime import datetime
from deepface import DeepFace
from mtcnn import MTCNN  # For face detection

# Path to student images folder
STUDENT_IMAGES_PATH = "C:/Users/Asus/Videos/images"
ATTENDANCE_FILE = "attendance.csv"

# Load MTCNN for face detection
detector = MTCNN()

# Load student images and create encodings using DeepFace
def load_and_encode_students():
    student_encodings = []
    student_names = []
    for file_name in os.listdir(STUDENT_IMAGES_PATH):
        image_path = os.path.join(STUDENT_IMAGES_PATH, file_name)
        image = cv2.imread(image_path)
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Detect the face in the image
        detection = detector.detect_faces(rgb_image)
        if detection:
            x, y, width, height = detection[0]['box']
            face = rgb_image[y:y+height, x:x+width]

            # Preprocess the face for DeepFace (no need to resize, DeepFace handles it)
            face_image_path = "temp_face.jpg"
            cv2.imwrite(face_image_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))  # Save the face image

            # Get face encoding using DeepFace
            face_embedding = DeepFace.represent(face_image_path, model_name="Facenet")[0]["embedding"]

            student_encodings.append(face_embedding)
            student_names.append(os.path.splitext(file_name)[0])

    return student_encodings, student_names

# Function to calculate cosine similarity between two encodings
def cosine_similarity(encoding1, encoding2):
    return np.dot(encoding1, encoding2) / (np.linalg.norm(encoding1) * np.linalg.norm(encoding2))

# Mark attendance in a CSV file
def mark_attendance(name):
    with open(ATTENDANCE_FILE, "a") as file:
        now = datetime.now()
        time_stamp = now.strftime("%Y-%m-%d %H:%M:%S")
        file.write(f"{name},{time_stamp}\n")

# Load students and encode their faces
student_encodings, student_names = load_and_encode_students()

# Initialize webcam or CCTV feed
video_capture = cv2.VideoCapture("C:/Users/Asus/Downloads/Untitled_Project_V2.mp4")  # Change to 0 for webcam

print("Starting attendance detection...")
while True:
    ret, frame = video_capture.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    detections = detector.detect_faces(rgb_frame)
    for detection in detections:
        x, y, width, height = detection['box']
        face = rgb_frame[y:y+height, x:x+width]

        # Preprocess the face
        face_image_path = "temp_face.jpg"
        cv2.imwrite(face_image_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))  # Save the face image

        # Get encoding for the detected face using DeepFace
        face_embedding = DeepFace.represent(face_image_path, model_name="Facenet")[0]["embedding"]

        # Compare with known encodings
        similarities = [cosine_similarity(face_embedding, student_encoding) for student_encoding in student_encodings]
        best_match_index = np.argmax(similarities)

        # If similarity exceeds a threshold, mark attendance
        if similarities[best_match_index] > 0.8:  # Adjust the threshold as needed
            name = student_names[best_match_index]
            mark_attendance(name)

            # Draw a rectangle around the face and show name
            cv2.rectangle(frame, (x, y), (x+width, y+height), (0, 255, 0), 2)
            cv2.putText(frame, name, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    # Display the video feed
    cv2.imshow('Attendance Detection', frame)

    # Quit with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
video_capture.release()
cv2.destroyAllWindows()
print("Attendance detection stopped.")
# Out:
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\anaconda\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 25-01-07 15:56:10 - Directory C:\Users\Asus\.deepface has been created
# 25-01-07 15:56:10 - Directory C:\Users\Asus\.deepface\weights has been created
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 54
#      51         file.write(f"{name},{time_stamp}\n")
#      53 # Load students and encode their faces
# ---> 54 student_encodings, student_names = load_and_encode_students()
#      56 # Initialize webcam or CCTV feed
#      57 video_capture = cv2.VideoCapture("C:/Users/Asus/Downloads/Untitled_Project_V2.mp4")  # Change to 0 for webcam
#
# Cell In[3], line 35, in load_and_encode_students()
#      32 cv2.imwrite(face_image_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))  # Save the face image
#      34 # Get face encoding using DeepFace
# ---> 35 face_embedding = DeepFace.represent(face_image_path, model_name="Facenet")[0]["embedding"]
#      37 student_encodings.append(face_embedding)
#      38 student_names.append(os.path.splitext(file_name)[0])
#
# File ~\anaconda3\anaconda\Lib\site-packages\deepface\DeepFace.py:418, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     359 def represent(
#     360     img_path: Union[str, np.ndarray],
#     361     model_name: str = "VGG-Face",
#    (...)
#     368     max_faces: Optional[int] = None,
#     369 ) -> List[Dict[str, Any]]:
#     370     """
#     371     Represent facial images as multi-dimensional vector embeddings.
#     372
#    (...)
#     416             to 'skip', the confidence will be 0 and is nonsensical.
#     417     """
# --> 418     return representation.represent(
#     419         img_path=img_path,
#     420         model_name=model_name,
#     421         enforce_detection=enforce_detection,
#     422         detector_backend=detector_backend,
#     423         align=align,
#     424         expand_percentage=expand_percentage,
#     425         normalization=normalization,
#     426         anti_spoofing=anti_spoofing,
#     427         max_faces=max_faces,
#     428     )
#
# File ~\anaconda3\anaconda\Lib\site-packages\deepface\modules\representation.py:68, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#      24 """
#      25 Represent facial images as multi-dimensional vector embeddings.
#      26
#    (...)
#      64         to 'skip', the confidence will be 0 and is nonsensical.
#      65 """
#      66 resp_objs = []
# ---> 68 model: FacialRecognition = modeling.build_model(
#      69     task="facial_recognition", model_name=model_name
#      70 )
#      72 # ---------------------------------
#      73 # we have run pre-process in verification. so, this can be skipped if it is coming from verify.
#      74 target_size = model.input_shape
#
# AttributeError: module 'deepface.modules.modeling' has no attribute 'build_model'

# %%
pip install tf-keras
# Out:
# Collecting tf-kerasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading tf_keras-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tf-keras) (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (75.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.0)
# Downloading tf_keras-2.18.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 270.5 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.7 MB 270.5 kB/s eta 0:00:05
#    ------------------ --------------------- 0.8/1.7 MB 404.2 kB/s eta 0:00:03
#    ------------------------ --------------- 1.0/1.7 MB 484.0 kB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 484.0 kB/s eta 0:00:02
#    ------------------------------ --------- 1.3/1.7 MB 512.2 kB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 512.2 kB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 512.2 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 496.3 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 496.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 503.5 kB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.18.0

# %%
pip install deepface==0.0.72
# Out:
# Collecting deepface==0.0.72
#   Downloading deepface-0.0.72-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (2.1.4)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (4.65.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (5.2.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (10.2.0)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (4.9.0.80)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (2.18.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (3.7.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (2.2.5)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface==0.0.72) (0.0.17)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface==0.0.72) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface==0.0.72) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface==0.0.72) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface==0.0.72) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface==0.0.72) (4.12.2)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface==0.0.72) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface==0.0.72) (2.31.0)
# Requirement already satisfied: absl-py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (2.1.0)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (0.0.8)
# Requirement already satisfied: h5py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (3.12.1)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (0.4.1)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface==0.0.72) (23.1)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface==0.0.72) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface==0.0.72) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface==0.0.72) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface==0.0.72) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface==0.0.72) (2023.3)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface==0.0.72) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (75.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (0.31.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tqdm>=4.30.0->deepface==0.0.72) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface==0.0.72) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface==0.0.72) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.72) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.72) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.72) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.72) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface==0.0.72) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface==0.0.72) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface==0.0.72) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface==0.0.72) (0.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface==0.0.72) (0.7.2)
# Downloading deepface-0.0.72-py3-none-any.whl (62 kB)
# Installing collected packages: deepface
#   Attempting uninstall: deepface
#     Found existing installation: deepface 0.0.93
#     Uninstalling deepface-0.0.93:
#       Successfully uninstalled deepface-0.0.93
# Successfully installed deepface-0.0.72
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 import os
#       4 from datetime import datetime
# ----> 5 from deepface import DeepFace
#       6 from mtcnn import MTCNN  # For face detection
#       8 # Path to student images folder
#
# File ~\anaconda3\anaconda\Lib\site-packages\deepface\DeepFace.py:15
#      12 from tqdm import tqdm
#      13 import pickle
# ---> 15 from deepface.basemodels import VGGFace, OpenFace, Facenet, Facenet512, FbDeepFace, DeepID, DlibWrapper, ArcFace, Boosting
#      16 from deepface.extendedmodels import Age, Gender, Race, Emotion
#      17 from deepface.commons import functions, realtime, distance as dst
#
# File ~\anaconda3\anaconda\Lib\site-packages\deepface\basemodels\FbDeepFace.py:8
#       6 from tensorflow import keras
#       7 from tensorflow.keras.models import Model, Sequential
# ----> 8 from tensorflow.keras.layers import Convolution2D, LocallyConnected2D, MaxPooling2D, Flatten, Dense, Dropout
#      10 from deepface.commons import functions
#      12 #-------------------------------------
#
# ImportError: cannot import name 'LocallyConnected2D' from 'tensorflow.keras.layers' (C:\Users\Asus\anaconda3\anaconda\Lib\site-packages\keras\_tf_keras\keras\layers\__init__.py)

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\asus\anaconda3\anaconda\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in c:\users\asus\anaconda3\anaconda\lib\site-packages (3.7.0)
# Requirement already satisfied: absl-py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras) (23.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade deepface
# Out:
# Requirement already satisfied: deepface in c:\users\asus\anaconda3\anaconda\lib\site-packages (0.0.72)
# Collecting deepface
#   Using cached deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.1.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (10.2.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (4.9.0.80)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.18.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (3.7.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (2.2.5)
# Requirement already satisfied: flask-cors>=4.0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (5.0.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from deepface) (23.0.0)
# Requirement already satisfied: termcolor in c:\users\asus\anaconda3\anaconda\lib\site-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\anaconda\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: absl-py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (13.3.5)
# Requirement already satisfied: namex in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (3.12.1)
# Requirement already satisfied: optree in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\asus\anaconda3\anaconda\lib\site-packages (from keras>=2.2.0->deepface) (0.4.1)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from mtcnn>=0.1.0->deepface) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests>=2.27.1->deepface) (2024.2.2)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (75.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\asus\anaconda3\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Using cached deepface-0.0.93-py3-none-any.whl (108 kB)
# Installing collected packages: deepface
#   Attempting uninstall: deepface
#     Found existing installation: deepface 0.0.72
#     Uninstalling deepface-0.0.72:
#       Successfully uninstalled deepface-0.0.72
# Successfully installed deepface-0.0.93
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from datetime import datetime
from deepface import DeepFace
from mtcnn import MTCNN  # For face detection

# Path to student images folder
STUDENT_IMAGES_PATH = "C:/Users/Asus/Videos/images"
ATTENDANCE_FILE = "attendance.csv"

# Load MTCNN for face detection
detector = MTCNN()

# Load student images and create encodings using DeepFace
def load_and_encode_students():
    student_encodings = []
    student_names = []
    for file_name in os.listdir(STUDENT_IMAGES_PATH):
        image_path = os.path.join(STUDENT_IMAGES_PATH, file_name)
        image = cv2.imread(image_path)
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Detect the face in the image
        detection = detector.detect_faces(rgb_image)
        if detection:
            x, y, width, height = detection[0]['box']
            face = rgb_image[y:y+height, x:x+width]

            # Preprocess the face for DeepFace (no need to resize, DeepFace handles it)
            face_image_path = "temp_face.jpg"
            cv2.imwrite(face_image_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))  # Save the face image

            # Get face encoding using DeepFace
            face_embedding = DeepFace.represent(face_image_path, model_name="Facenet")[0]["embedding"]

            student_encodings.append(face_embedding)
            student_names.append(os.path.splitext(file_name)[0])

    return student_encodings, student_names

# Function to calculate cosine similarity between two encodings
def cosine_similarity(encoding1, encoding2):
    return np.dot(encoding1, encoding2) / (np.linalg.norm(encoding1) * np.linalg.norm(encoding2))

# Mark attendance in a CSV file
def mark_attendance(name):
    with open(ATTENDANCE_FILE, "a") as file:
        now = datetime.now()
        time_stamp = now.strftime("%Y-%m-%d %H:%M:%S")
        file.write(f"{name},{time_stamp}\n")
    print(f"Attendance marked for: {name}")

# Load students and encode their faces
student_encodings, student_names = load_and_encode_students()
print("Student encodings loaded.")

# Initialize webcam or CCTV feed
video_capture = cv2.VideoCapture("C:/Users/Asus/Downloads/Untitled_Project_V2.mp4")  # Change to 0 for webcam

if not video_capture.isOpened():
    print("Error: Could not open video stream.")
else:
    print("Video stream opened successfully.")

print("Starting attendance detection...")
while True:
    ret, frame = video_capture.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    detections = detector.detect_faces(rgb_frame)
    if not detections:
        print("No faces detected in this frame.")
    else:
        for detection in detections:
            x, y, width, height = detection['box']
            face = rgb_frame[y:y+height, x:x+width]

            # Preprocess the face
            face_image_path = "temp_face.jpg"
            cv2.imwrite(face_image_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))  # Save the face image

            # Get encoding for the detected face using DeepFace
            face_embedding = DeepFace.represent(face_image_path, model_name="Facenet")[0]["embedding"]

            # Compare with known encodings
            similarities = [cosine_similarity(face_embedding, student_encoding) for student_encoding in student_encodings]
            best_match_index = np.argmax(similarities)

            # If similarity exceeds a threshold, mark attendance
            if similarities[best_match_index] > 0.8:  # Adjust the threshold as needed
                name = student_names[best_match_index]
                mark_attendance(name)

                # Draw a rectangle around the face and show name
                cv2.rectangle(frame, (x, y), (x+width, y+height), (0, 255, 0), 2)
                cv2.putText(frame, name, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    # Display the video feed
    cv2.imshow('Attendance Detection', frame)

    # Quit with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
video_capture.release()
cv2.destroyAllWindows()
print("Attendance detection stopped.")
# Out:
# Student encodings loaded.
# Video stream opened successfully.
# Starting attendance detection...
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# No faces detected in this frame.
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: kim
# Attendance marked for: ratan
# Attendance marked for: ratan
# Attendance marked for: ratan
# Attendance marked for: ratan
# Attendance marked for: ratan
# Error: Could not read frame.
# Attendance detection stopped.
